# %%
import random

# %%
class Character:
    def __init__(self, name, STR, LUK, DEX, INT):
        self.name = name
        self.STR = STR
        self.LUK = LUK
        self.DEX = DEX
        self.INT = INT

    @staticmethod
    def roll_dice():
        return random.randint(4, 8), random.randint(4, 8), random.randint(4, 8), random.randint(4, 8)

# %%
Characters = []

while True:
    print('========== 메이플 캐릭터 만들기 ==========')
    print('1️⃣ 캐릭터 생성')
    print('2️⃣ 캐릭터 목록 보기')
    print('3️⃣ 종료')
    choice = int(input('번호를 입력하세요 : '))
    print('=====================================')
    
    if choice == 1:
        name = input('✏️ 캐릭터 명을 입력하세요 : ')
        print('🎲 주사위를 굴리세요!')

        while True:
            STR, LUK, DEX, INT = Character.roll_dice()
            print(f'STR: {STR} / LUK: {LUK} / DEX: {DEX} / INT: {INT}')
            
            again = input('🌀 재시도 하시겠습니까? (Y/N)').upper()
            if again == 'Y':
                continue
            else:
                confirm = input('🪄 캐릭터 등록 하시겠습니까? (Y/N)').upper()
                if confirm == 'Y':

                    user = Character(name, STR, LUK, DEX, INT)
                    Characters.append(user)
                    
                    print('✅ 캐릭터 등록 완료')
                    break
                else:
                    continue
                
    if choice == 2:
        if not Characters:
            print('❌ 등록된 캐릭터가 없습니다.')
        else:
            for c in Characters:
                print(f'이름: {c.name} / STR: {c.STR} / LUK: {c.LUK} / DEX: {c.DEX} / INT: {c.INT}')

    if choice == 3:
        print('메이플 캐릭터 만들기를 종료합니다.')
        break;
# Out:
# ========== 메이플 캐릭터 만들기 ==========
# 1️⃣ 캐릭터 생성
# 2️⃣ 캐릭터 목록 보기
# 3️⃣ 종료
# 번호를 입력하세요 :  2
# =====================================
# ❌ 등록된 캐릭터가 없습니다.
# ========== 메이플 캐릭터 만들기 ==========
# 1️⃣ 캐릭터 생성
# 2️⃣ 캐릭터 목록 보기
# 3️⃣ 종료
# 번호를 입력하세요 :  3
# =====================================
# 메이플 캐릭터 만들기를 종료합니다.
